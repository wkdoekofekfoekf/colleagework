# %%
import cv2, sys
from matplotlib import pyplot as plt
import numpy as np

image = cv2.imread('stone.jpg')
image_gray = cv2.imread('stone.jpg', cv2.IMREAD_GRAYSCALE)

# %%
b,g,r = cv2.split(image)
image2 = cv2.merge([r,g,b])
 
plt.imshow(image2)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
cv2.imshow('image', image)
cv2.imshow('image_gray', image_gray)
 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
# Requirement already satisfied: numpy>=1.17.3 in ./anaconda3/envs/mxnet1.9_p38/lib/python3.8/site-packages (from opencv-python) (1.21.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 8.7 MB/s eta 0:00:01
# Requirement already satisfied: kiwisolver>=1.0.1 in ./anaconda3/envs/mxnet1.9_p38/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./anaconda3/envs/mxnet1.9_p38/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.32.0-py3-none-any.whl (900 kB)
#      |████████████████████████████████| 900 kB 95.4 MB/s eta 0:00:01
# Requirement already satisfied: pillow>=6.2.0 in ./anaconda3/envs/mxnet1.9_p38/lib/python3.8/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./anaconda3/envs/mxnet1.9_p38/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/envs/mxnet1.9_p38/lib/python3.8/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in ./anaconda3/envs/mxnet1.9_p38/lib/python3.8/site-packages (from matplotlib) (1.21.2)
# Requirement already satisfied: pyparsing>=2.2.1 in ./anaconda3/envs/mxnet1.9_p38/lib/python3.8/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six>=1.5 in ./anaconda3/envs/mxnet1.9_p38/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: fonttools, matplotlib
# Successfully installed fonttools-4.32.0 matplotlib-3.5.1

# %%
blur = cv2.GaussianBlur(image_gray, ksize=(3,3), sigmaX=0)
ret, thresh1 = cv2.threshold(blur, 127, 255, cv2.THRESH_BINARY)

# %%
blur = cv2.GaussianBlur(image_gray, ksize=(5,5), sigmaX=0)
ret, thresh1 = cv2.threshold(blur, 127, 255, cv2.THRESH_BINARY)
