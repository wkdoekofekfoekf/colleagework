# %%
import pandas as pd
import shutil
import os, shutil
import os, glob, numpy as np

# %%
cd C:\Users\kimyeongmin\Desktop\eotPartsSample\outer
# Out:
# C:\Users\kimyeongmin\Desktop\eotPartsSample\outer

# %%
abc = pd.read_csv("eotfinal1.csv")

# %%
abcc = abc[abc['상하의'] == 5]

# %%
abcc = list(abcc['파일명'])

# %%
for i in range(len(c)):
    
    if c[i] in abcc:
         #<-파일명
        shutil.move('./'+cd[c.index(c[i])], './3')

# %%
# Out:
# 9232

# %%
import os
import glob
files = glob.glob("*.png")
for name in files:
    if not os.path.isdir(name):
        src = os.path.splitext(name)
        os.rename(name,src[0]+'.jpg')
#이미지 파일 jpg있는거 png로 변경

# %%
cd
# Out:
# ['005230.png',
#  '005231.png',
#  '005232.png',
#  '005233.png',
#  '005235.png',
#  '005236.png',
#  '005243.png',
#  '005244.png',
#  '005246.png',
#  '005247.png',
#  '005248.png',
#  '005249.png',
#  '005250.png',
#  '005251.png',
#  '005252.png',
#  '005254.png',
#  '005255.png',
#  '005256.png',
#  '005257.png',
#  '005258.png',
#  '005259.png',
#  '005260.png',
#  '005261.png',
#  '005262.png',
#  '005263.png',
#  '005264.png',
#  '005265.png',
#  '005266.png',
#  '005267.png',
#  '005268.png',
#  '005269.png',
#  '005270.png',
#  '005271.png',
#  '005272.png',
#  '005273.png',
#  '005274.png',
#  '005275.png',
#  '005276.png',
#  '005277.png',
#  '005278.png',
#  '005279.png',
#  '005280.png',
#  '005281.png',
#  '005282.png',
#  '005283.png',
#  '005284.png',
#  '005285.png',
#  '005286.png',
#  '005287.png',
#  '005288.png',
#  '005289.png',
#  '005290.png',
#  '005291.png',
#  '005292.png',
#  '005293.png',
#  '005294.png',
#  '005295.png',
#  '005296.png',
# ...

# %%
cd = os.listdir(os.getcwd())

#이미지 목록읽어오기

# %%
i = 2
for k in range(61,301):
    file_path = 'C:/Users/kimyeongmin/Desktop/new/test/ame/'+str(k)
    file_names = os.listdir(file_path)
    file_names
    file_path1 = 'C:/Users/kimyeongmin/Desktop/new/test/ame/'
    for name in file_names:
        src = os.path.join(file_path, name)
        dst = str(i) + '.png'
        dst = os.path.join(file_path1, dst)
        os.rename(src, dst)
        i += 1
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# C:\Users\KIMYEO~1\AppData\Local\Temp/ipykernel_19428/3565061382.py in <module>
#       9         dst = str(i) + '.png'
#      10         dst = os.path.join(file_path1, dst)
# ---> 11         os.rename(src, dst)
#      12         i += 1
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'C:/Users/kimyeongmin/Desktop/new/train/ame/300\\top.png' -> 'C:/Users/kimyeongmin/Desktop/new/train/ame/1440.png'

# %%
        src = os.path.join(file_path, name)
        dst = str(i) + '.png'
        dst = os.path.join(file_path1, dst)
        os.rename(src, dst)
        i += 1

# %%
src
# Out:
# 'C:/Users/kimyeongmin/Desktop/new/train/ame/61\\top.png'

# %%
for i in range(61,len(c)+61):
    files = glob.glob(str(i)+"/*.png")
    for j in files:
        shutil.move('C:/Users/kimyeongmin/Desktop/new/train/golf/'+j, 'C:/Users/kimyeongmin/Desktop/new/train/golf')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# C:\Users\KIMYEO~1\AppData\Local\Temp/ipykernel_19428/4143412580.py in <module>
#       2     files = glob.glob(str(i)+"/*.png")
#       3     for j in files:
# ----> 4         shutil.move('C:/Users/kimyeongmin/Desktop/new/train/golf/'+j, 'C:/Users/kimyeongmin/Desktop/new/train/golf')
#       5
#
# C:\anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     810
#     811         if os.path.exists(real_dst):
# --> 812             raise Error("Destination path '%s' already exists" % real_dst)
#     813     try:
#     814         os.rename(src, real_dst)
#
# Error: Destination path 'C:/Users/kimyeongmin/Desktop/new/train/golf\golf_0_1057.png' already exists

# %%
os.path.join(str(i), filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\KIMYEO~1\AppData\Local\Temp/ipykernel_19428/2730631556.py in <module>
# ----> 1 os.path.join(str(i), filename)
#
# NameError: name 'filename' is not defined

# %%
import shutil
import os
src = 'scrFolder'
dst = './dstFolder/'
filelist = []

files = os.listdir( src )
for filename in files:
    filelist.append(filename)
    fullpath = src + '/' + filename
    shutil.move(fullpath, dst)
# Out:
# '62\\bag.png'

# %%
shutil.move(os.path.join(src, filename), os.path.join(dst, filename))
# Out:
# <module 'ntpath' from 'C:\\anaconda3\\lib\\ntpath.py'>
