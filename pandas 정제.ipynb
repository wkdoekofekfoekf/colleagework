# %%
from keras.preprocessing.image import img_to_array
from keras.models import load_model
from PIL import Image
import io
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_24706/1346851462.py in <module>
# ----> 1 from keras.preprocessing.image import img_to_array
#       2 from keras.models import load_model
#       3 from PIL import Image
#       4 import io
#
# ~/anaconda3/lib/python3.9/site-packages/keras/__init__.py in <module>
#      19 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python import tf2
#      22 from keras import distribute
#      23
#
# ImportError: cannot import name 'tf2' from 'tensorflow.python' (unknown location)

# %%
pwd
# Out:
# '/home/ubuntu'

# %%
abc = pd.read_csv("eot1.csv", encoding = 'cp949')
# Out:
# C:\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
model = load_model('model_class.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_24706/3423268541.py in <module>
# ----> 1 model = load_model('model_class.h5')
#
# NameError: name 'load_model' is not defined

# %%
img = request.files["file"].read()
img = Image.open(io.BytesIO(img))
img = img.resize((256, 256))
img = img_to_array(img)
img = img.reshape((1, img.shape[0], img.shape[1], img.shape[2]))
pred = model_for_man.predict(img)
label = pred.argmax()
# Out:
#          파일명  리뷰  찜      가격  카테고리       네이버  성별  컬러  톤  패턴  계절  상하의      관리코드  \
# 0       5230   1  0  194700  2176  50000639   2   9  3   1   3    1  RS000430
# 1       5231   1  0   93600  2176  50000639   2   1  3   1   3    1  RS000071
# 2       5232   1  0   23900   601  50000808   2   7  2   2   3    3  NT000762
# 3       5233   1  0  630000   601  50000808   2  10  3   2   3    3  NT000680
# 4       5234   1  0   84200  1869  50000832   1   5  3  10   5    1  AC004260
# ...      ...  .. ..     ...   ...       ...  ..  .. ..  ..  ..  ...       ...
# 53753  59798   1  0  182500  2176  50000639   2   7  3   1   3    1  RS000382
# 53754  59799   1  0  182500  2176  50000639   2   3  3   1   3    1  RS000170
# 53755  59800   0  0   45000  1929  50000647   1   4  3   1   3    1  BB000314
# 53756  59801   1  0   31480  1451  50000810   2   4  1   1   3    2  MT000269
# 53757  59802   1  0   14500   612  50000808   2   2  2   1   3    3  OI000012
#
# ...

# %% [raw]
# ab

# %%
# Out:
#          파일명  리뷰  찜      가격  카테고리       네이버  성별  컬러  톤  패턴  계절  상하의      관리코드  \
# 4       5234   1  0   84200  1869  50000832   1   5  3  10   5    1  AC004260
# 7       5237   0  0   56700  2059  50000817   2   1  2  10   5    1  KW000758
# 8       5238   0  0   37830  2059  50000817   2   5  3   1   5    1  KW000935
# 9       5239   0  0   37830  2059  50000817   2   1  3   8   5    1  KW000809
# 10      5240   0  0   57230  2059  50000817   2   8  1   1   5    1  KW001019
# ...      ...  .. ..     ...   ...       ...  ..  .. ..  ..  ..  ...       ...
# 53716  59761   0  0   16740  2059  50000817   2   6  2  10   5    1  KW000973
# 53720  59765   0  0  114070  2059  50000817   2   1  2   1   5    1  KW000762
# 53725  59770   1  0   22900  1869  50000832   1   4  2  10   5    1  AC004248
# 53744  59789   1  0   29900  1869  50000832   1   8  2   3   5    1  AC004418
# 53751  59796   1  0   45670  1869  50000832   1   9  3  10   5    1  AC004432
#
# ...

# %%
import os



for i in range(1,13):
    os.mkdir(str(i))




#디렉터리만들기

# %%
c = os.listdir(os.getcwd())
len(c)
#이미지 목록읽어오기
# Out:
# 52961

# %%
for i in range(len(c)):
    c[i] = c[i].rstrip('.png')
#이미지목록에서 확장자제거

# %%
a
# Out:
# 4        False
# 7        False
# 8        False
# 9        False
# 10       False
#          ...
# 53716    False
# 53720    False
# 53725    False
# 53744    False
# 53751    False
# Name: 파일명, Length: 1886, dtype: bool

# %%
for i in range(len(c)):
    f = len(a[a['파일명'] == int(c[i])])
    if f!=0:

        bb = a[a['파일명'] == int(c[i])]['파일명'].values[0]

        shutil.move(str(bb).zfill(6)+'.png', './1')

    elif f == 0:
        pass

# %%
a['파일명'] = int(c[i])
# Out:
# C:\Users\KIMYEO~1\AppData\Local\Temp/ipykernel_6132/2233685137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['파일명'] = int(c[i])

# %%
a
# Out:
# 4        False
# 7        False
# 8        False
# 9        False
# 10       False
#          ...
# 53716    False
# 53720    False
# 53725    False
# 53744    False
# 53751    False
# Name: 파일명, Length: 1886, dtype: bool

# %%
a = abc[abc['관리코드'].str.contains('RR|KW|AC|BD|KN|KJ|KE|AD|DZ|EE|KS|EJ|EI|AE|KU|LD|KF|KG|KI|KW')]['파일명'] == int(c[i])

# %%
a = abc[abc['관리코드'].str.contains('RR|KW|AC|BD|KN|KJ|KE|AD|DZ|EE|KS|EJ|EI|AE|KU|LD|KF|KG|KI|KW')]

# %%
abc[abc['관리코드'].str.contains('BY')]
# Out:
#          파일명   리뷰    찜      가격  카테고리       네이버  성별  컬러  톤  패턴  계절  상하의  \
# 39      5270   99   99   71200   349  50000833   1   5  3   1   5    1
# 75      5306   99   99   39900   399  50000833   1   5  3   1   5    1
# 146     5377   99   99   49900   349  50000833   1   7  2   1   5    1
# 176     5407   99   99   49900   349  50000833   1  10  3   1   5    1
# 374     5605   99   99  299000   349  50000833   1   9  3  10   5    1
# 2203    7435  100  100  288000   399  50000833   1  10  3   1   5    1
# 4584    9816   99   99  684300  1220  50000833   1  10  3  10   5    1
# 4589    9821   99   99  676800  1220  50000833   1  10  3  10   5    1
# 4590    9822   99   99  676800  1220  50000833   1   8  3   1   5    1
# 4606    9838   99   99  738900  1220  50000833   1  10  3  10   5    1
# 4607    9839   99   99  738900  1220  50000833   1   4  2   1   5    1
# 4608    9840   99   99  738900  1220  50000833   1   3  1   1   5    1
# ...

# %%
a = abc[abc['관리코드'].str.contains('RR|KW|AC|BD|KN|KJ|KE|AD|DZ|EE|KS|EJ|EI|AE|KU')]['파일명'] == int(c[i])
# Out:
# C:\Users\KIMYEO~1\AppData\Local\Temp/ipykernel_6132/4161866468.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a = abc[abc[abc['관리코드'].str.contains('RR|KW|AC|BD|KN|KJ|KE|AD|DZ|EE|KS|EJ|EI|AE|KU')]['파일명'] == int(c[i])]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# C:\Users\KIMYEO~1\AppData\Local\Temp/ipykernel_6132/4161866468.py in <module>
# ----> 1 a = abc[abc[abc['관리코드'].str.contains('RR|KW|AC|BD|KN|KJ|KE|AD|DZ|EE|KS|EJ|EI|AE|KU')]['파일명'] == int(c[i])]
#
# C:\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# ...

# %%
a['파일명']
# Out:
# 4         5234
# 7         5237
# 8         5238
# 9         5239
# 10        5240
#          ...
# 53716    59761
# 53720    59765
# 53725    59770
# 53744    59789
# 53751    59796
# Name: 파일명, Length: 1614, dtype: int64

# %%
# Out:
#          파일명  리뷰  찜      가격  카테고리       네이버  성별  컬러  톤  패턴  계절  상하의      관리코드  \
# 4       5234   1  0   84200  1869  50000832   1   5  3  10   5    1  AC004260
# 7       5237   0  0   56700  2059  50000817   2   1  2  10   5    1  KW000758
# 8       5238   0  0   37830  2059  50000817   2   5  3   1   5    1  KW000935
# 9       5239   0  0   37830  2059  50000817   2   1  3   8   5    1  KW000809
# 10      5240   0  0   57230  2059  50000817   2   8  1   1   5    1  KW001019
# ...      ...  .. ..     ...   ...       ...  ..  .. ..  ..  ..  ...       ...
# 53716  59761   0  0   16740  2059  50000817   2   6  2  10   5    1  KW000973
# 53720  59765   0  0  114070  2059  50000817   2   1  2   1   5    1  KW000762
# 53725  59770   1  0   22900  1869  50000832   1   4  2  10   5    1  AC004248
# 53744  59789   1  0   29900  1869  50000832   1   8  2   3   5    1  AC004418
# 53751  59796   1  0   45670  1869  50000832   1   9  3  10   5    1  AC004432
#
# ...
